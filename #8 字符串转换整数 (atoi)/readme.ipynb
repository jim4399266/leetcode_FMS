# %% [markdown]
# 该题的状态较少，题目定义4中状态，每种状态遇到空格，符号，数字、其他又会转入不同的状态，状态与转移图如下

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 由上图可以得到一个状态转移表

# %% [markdown]
# ![image.png](attachment:image.png)
